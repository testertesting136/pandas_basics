# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 3.0.5

# %%
temps = [45, 98, 78, 67, 12]
print(temps)
# Out:
# [45, 98, 78, 67, 12]

# %%
data = {
    "ids" : ["A1", "A2", "A3", "B1"],
    "treatments" : ["Control", "Control", "Fertilizer", "Fertilizer"],
    "heights" : [12.4, 13.1, 15.8, 16.21]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   ids  treatments  heights
# 0  A1     Control    12.40
# 1  A2     Control    13.10
# 2  A3  Fertilizer    15.80
# 3  B1  Fertilizer    16.21

# %%
print(df.shape)
# Out:
# (4, 3)

# %%
print(df.columns)
# Out:
# Index(['ids', 'treatments', 'heights'], dtype='str')

# %%
print(list(df.columns))
# Out:
# ['ids', 'treatments', 'heights']

# %%
heights = df["heights"] #Series

# %%
average_height = heights.mean()
print(f"Average Height: {average_height}")
# Out:
# Average Height: 14.3775

# %%
df.head()
# Out:
#   ids  treatments  heights
# 0  A1     Control    12.40
# 1  A2     Control    13.10
# 2  A3  Fertilizer    15.80
# 3  B1  Fertilizer    16.21

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ids         4 non-null      str
#  1   treatments  4 non-null      str
#  2   heights     4 non-null      float64
# dtypes: float64(1), str(2)
# memory usage: 228.0 bytes
